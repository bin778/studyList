# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/MNIST Model')

# %%
# !python predict.py
# Out:
# cpu
# Accuracy: 0.9808
# Accuracy: 0.9500
# Figure(640x480)
# Predict: 7.0
# Figure(640x480)
# Predict: 2.0
# Figure(640x480)
# Predict: 1.0
# Figure(640x480)
# Predict: 0.0
# Figure(640x480)
# Predict: 4.0
# Figure(640x480)
# Predict: 1.0
# Figure(640x480)
# Predict: 4.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 5.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 0.0
# Figure(640x480)
# Predict: 6.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 0.0
# Figure(640x480)
# Predict: 1.0
# Figure(640x480)
# Predict: 5.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 7.0
# Figure(640x480)
# Predict: 8.0
# Figure(640x480)
# Predict: 4.0

# %%
# !python train.py --model_fn modelGPU.pth --gpu_id 0 --batch_size 256 --n_epochs 20 --n_layers 5
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# ImageClassifier(
#   (layers): Sequential(
#     (0): Block(
#       (block): Sequential(
#         (0): Linear(in_features=784, out_features=630, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(630, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (block): Sequential(
#         (0): Linear(in_features=630, out_features=476, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(476, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Block(
#       (block): Sequential(
#         (0): Linear(in_features=476, out_features=322, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): BatchNorm1d(322, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Block(
# ...

# %%
# !python predictgpu.py
# Out:
# cuda
# Accuracy: 0.9834
# Accuracy: 1.0000
# Figure(640x480)
# Predict: 7.0
# Figure(640x480)
# Predict: 2.0
# Figure(640x480)
# Predict: 1.0
# Figure(640x480)
# Predict: 0.0
# Figure(640x480)
# Predict: 4.0
# Figure(640x480)
# Predict: 1.0
# Figure(640x480)
# Predict: 4.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 5.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 0.0
# Figure(640x480)
# Predict: 6.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 0.0
# Figure(640x480)
# Predict: 1.0
# Figure(640x480)
# Predict: 5.0
# Figure(640x480)
# Predict: 9.0
# Figure(640x480)
# Predict: 7.0
# Figure(640x480)
# Predict: 3.0
# Figure(640x480)
# Predict: 4.0

# %%
# !python predict.py >> predict.txt

# %%
# !python predictgpu.py >> predictgpu.txt
